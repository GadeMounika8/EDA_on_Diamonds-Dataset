# %% [markdown]
# # Importing all required Libraries:

# %%
# importing all required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Dataset:

# %%
# Load the Dataset
df = pd.read_csv(r"C:\Users\mouni\Downloads\diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # Data Cleaning:

# %%
# gives number of rows and columns
df.shape
# Out:
# (53940, 10)

# %%
# Top 10 Records
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
# number of duplicate values in a DataFrame
df.duplicated().sum()
# Out:
# 146

# %%
# dropping the duplicates from the DataFrame
df.drop_duplicates(inplace = True)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
# removing outliers in carat column by using IQR Method
Q1 = df['carat'].quantile(0.25)
Q3 = df['carat'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['carat'] > bmi_lower_bound)&(df['carat']<bmi_upper_bound)]
print(df.shape)
# Out:
# (51658, 10)

# %%
# removing outliers in depth column by using IQR Method
Q1 = df['depth'].quantile(0.25)
Q3 = df['depth'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['depth'] > bmi_lower_bound)&(df['depth']<bmi_upper_bound)]
print(df.shape)
# Out:
# (48673, 10)

# %%
# removing outliers in table column by using IQR Method
Q1 = df['table'].quantile(0.25)
Q3 = df['table'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['table'] > bmi_lower_bound)&(df['table']<bmi_upper_bound)]
print(df.shape)
# Out:
# (48340, 10)

# %%
# removing outliers in x column by using IQR Method
Q1 = df['x'].quantile(0.25)
Q3 = df['x'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['x'] > bmi_lower_bound)&(df['x']<bmi_upper_bound)]
print(df.shape)
# Out:
# (48335, 10)

# %%
# removing outliers in y column by using IQR Method
Q1 = df['y'].quantile(0.25)
Q3 = df['y'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['y'] > bmi_lower_bound)&(df['y']<bmi_upper_bound)]
print(df.shape)
# Out:
# (48334, 10)

# %%
# removing outliers in z column by using IQR Method
Q1 = df['z'].quantile(0.25)
Q3 = df['z'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['z'] > bmi_lower_bound)&(df['z']<bmi_upper_bound)]
print(df.shape)
# Out:
# (48326, 10)

# %% [markdown]
# # Data Exploration:

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [48326 rows x 10 columns]

# %%
# number of rows and columns in a DataFrame
df.shape
# Out:
# (48326, 10)

# %%
# All column names from a DF
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
# each column's datatype of a DataFrame
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
# Unique values of color column
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
# Number of Unique values in a color column
df['color'].nunique()
# Out:
# 7

# %%
# Unique values in cut column
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# number of unique values in a cut column
df['cut'].nunique()
# Out:
# 5

# %%
# Unique values in a clarity column
df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS2', 'VVS2', 'VVS1', 'VS1', 'I1', 'IF'],
#       dtype=object)

# %%
# number of unique values in clarity column
df['clarity'].nunique()
# Out:
# 8

# %%
# returns a Series that contain counts of unique values. 
df['color'].value_counts()
# Out:
# G    10410
# E     9030
# F     8696
# H     7247
# D     6269
# I     4485
# J     2189
# Name: color, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# SI1     11624
# VS2     11304
# VS1      7635
# SI2      7212
# VVS2     4841
# VVS1     3535
# IF       1722
# I1        453
# Name: clarity, dtype: int64

# %%
df['cut'].value_counts()
# Out:
# Ideal        20922
# Premium      12340
# Very Good    11140
# Good          3730
# Fair           194
# Name: cut, dtype: int64

# %%
# prints information about the DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48326 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    48326 non-null  float64
#  1   cut      48326 non-null  object
#  2   color    48326 non-null  object
#  3   clarity  48326 non-null  object
#  4   depth    48326 non-null  float64
#  5   table    48326 non-null  float64
#  6   price    48326 non-null  int64
#  7   x        48326 non-null  float64
#  8   y        48326 non-null  float64
#  9   z        48326 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# returns description of the data in the DataFrame. 
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  48326.000000  48326.000000  48326.000000  48326.000000  48326.000000
# mean       0.733973     61.802762     57.242042   3466.634917      5.601900
# std        0.393555      1.060668      2.005120   3362.746704      1.017343
# min        0.200000     59.100000     52.000000    326.000000      3.730000
# 25%        0.380000     61.200000     56.000000    906.000000      4.660000
# 50%        0.700000     61.900000     57.000000   2192.000000      5.590000
# 75%        1.020000     62.500000     59.000000   4918.750000      6.460000
# max        1.990000     64.500000     63.400000  18806.000000      8.200000
#
#                   y             z
# count  48326.000000  48326.000000
# mean       5.606907      3.463450
# std        1.011834      0.629113
# min        3.680000      1.410000
# 25%        4.670000      2.870000
# 50%        5.590000      3.450000
# 75%        6.460000      4.000000
# ...

# %%
pd.crosstab(df['color'], df['cut'])
# Out:
# cut    Fair  Good  Ideal  Premium  Very Good
# color
# D        28   511   2811     1502       1417
# E        25   703   3870     2177       2255
# F        36   695   3773     2159       2033
# G        44   702   4789     2692       2183
# H        39   537   2974     2043       1654
# I        11   363   1914     1159       1038
# J        11   219    791      608        560

# %%
pd.crosstab(df['color'], df['clarity'])
# Out:
# clarity  I1   IF   SI1   SI2   VS1   VS2  VVS1  VVS2
# color
# D        34   68  1941  1162   680  1622   241   521
# E        76  146  2239  1446  1210  2339   628   946
# F        97  369  1943  1311  1265  2077   706   928
# G        89  663  1787  1235  2045  2217   969  1405
# H        89  294  1949  1155  1102  1505   575   578
# I        48  136  1179   600   867   959   348   348
# J        20   46   586   303   466   585    68   115

# %%
pd.crosstab(df['clarity'], df['cut'])
# Out:
# cut      Fair  Good  Ideal  Premium  Very Good
# clarity
# I1         29    62    133      161         68
# IF          4    45   1202      217        254
# SI1        50  1229   4118     3222       3005
# SI2        47   754   2315     2327       1769
# VS1        18   506   3544     1881       1686
# VS2        36   770   4981     3098       2419
# VVS1        4   145   2035      593        758
# VVS2        6   219   2594      841       1181

# %%
# Top 5 records
df.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48

# %%
# displays all columns of object datypes in a DF
df.select_dtypes(include = 'object')
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# 5      Very Good     J    VVS2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [48326 rows x 3 columns]

# %%
# displays all columns of numeric datypes in a DF
df.select_dtypes(include = 'number')
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [48326 rows x 7 columns]

# %%
# extracting rows which contains Ideal category in cut columns
df.loc[df['cut'] == 'Ideal']
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 0       0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11      0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39      0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53925   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53929   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [20922 rows x 10 columns]

# %% [markdown]
# # Data Visualization: Using Matplotlib and Seaborn Libraries

# %% [markdown]
# # Uni-variate Data Analysis:

# %% [markdown]
# - The purpose of Uni-variate is to know the Distribution and Outliers of each column in a Dataset.

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'carat', data = df, kde = True, color = 'green', binwidth = 0.4)
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'depth', data = df, kde = True, color = 'red', binwidth = 2)
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'table', data = df, color = 'y', kde = True, binwidth = 2)
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'x', data = df, kde = True, color = 'indigo', binwidth = 1)
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'y', data = df, kde = True, color = 'orange', binwidth = 2)
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'z', data = df, kde = True, color = 'olive', binwidth = 2)
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.histplot(x = 'price', data = df, kde = True, color = 'purple', binwidth = 3)
plt.show();

# %%
plt.figure(figsize = (10,8))
sns.pairplot(df)

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'table', data = df, width = 0.4, color = 'yellow')
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'carat', data = df, width = 0.4, color = 'purple')
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'price', data = df, width = 0.4, color = 'green')
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'depth', data = df, width = 0.4, color = 'orange')
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'x', data = df, width = 0.4, color = 'cyan')
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'y', data = df, width = 0.4, color = 'pink')
plt.show();

# %%
plt.figure(figsize = (7,5))
sns.boxplot(y = 'z', data = df, width = 0.4, color = 'olive')
plt.show();

# %% [markdown]
# # Bi-variate Data Analysis:

# %% [markdown]
# - The purpose of Bi-variate Data Analysis is to know the relationships between two or more columns.

# %%
plt.figure(figsize = (6,5))
sns.boxplot(y = 'price', x = 'cut', data = df, palette = 'plasma')
plt.show();

# %%
plt.figure(figsize = (6,5))
sns.boxplot(y = 'price', x = 'color', data = df, palette = 'summer')
plt.show();

# %%
plt.figure(figsize = (6,5))
sns.boxplot(y = 'price', x = 'clarity', data = df, palette = 'PiYG')
plt.show();

# %%
sns.scatterplot(x = 'carat', y = 'price', hue = 'cut', data = df, 
                                                        s = 50,
                                                        palette= 'PiYG',
                                                        
                                                        x_jitter = 10,
                                                        y_jitter = 6,
                                                        
                                                    
                                                        alpha = 0.9,
                                                        edgecolor = 'k');

# %%
labels = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']
sns.heatmap(df.corr(), cmap = 'magma',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'k'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w',
                                                                     xticklabels = labels, 
                                                                     yticklabels = labels);

# %%
df.to_csv('DIAMONDS.csv')
